# %%
import pandas as pd

# %%
gname = ["Evelyn", "Jessica", "somto", "Edith", "Liza", "Madona", "Waje", "Tola", "Aishsa", "Latifa"]
gage = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
gheight = [5.5, 6.0 , 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
gscores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

gtable = pd.DataFrame({'name': gname, 'age': gage, 'height': gheight, 'scores': gscores})
print("Girls' Table:")
print(gtable)
# Out:
# Girls' Table:
#       name  age  height  scores
# 0   Evelyn   17     5.5      80
# 1  Jessica   16     6.0      85
# 2    somto   17     5.4      70
# 3    Edith   18     5.9      60
# 4     Liza   16     5.6      76
# 5   Madona   18     5.5      66
# 6     Waje   17     6.1      87
# 7     Tola   20     6.0      95
# 8   Aishsa   19     5.7      50
# 9   Latifa   17     5.5      49

# %%
bname = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]
bage = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
bheight = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
bscores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

btable = pd.DataFrame({'name': bname, 'age': bage, 'height': bheight, 'scores': bscores})
print("\nBoys' Table:") 
print(btable)
# Out:
# Boys' Table:
#       name  age  height  scores
# 0  Chinedu   19     5.7      74
# 1     Liam   16     5.9      87
# 2     Wale   18     5.8      75
# 3   Gbenga   17     6.1      68
# 4   Abiola   20     5.9      66
# 5     Kola   19     5.5      78
# 6    Kunle   16     6.1      87
# 7   George   18     5.4      98
# 8   Thomas   17     5.8      54
# 9   Wesley   19     5.7      60
